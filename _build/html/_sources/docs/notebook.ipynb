# %% [markdown]
# # Information visualisation project
#
# (Last updated: june 19, 2023)

# %% [markdown]
# TEST

# %%
# Import packages
import pandas as pd
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv("final_dataframe.csv")

# %%
df.head()
# Out:
#        Country  happiness_score  gdp_per_capita   family   health  freedom  \
# 0      Denmark            7.526         1.44178  1.16374  0.79504  0.57941
# 1  Switzerland            7.509         1.52733  1.14524  0.86303  0.58557
# 2      Iceland            7.501         1.42666  1.18326  0.86733  0.56624
# 3       Norway            7.498         1.57744  1.12690  0.79579  0.59609
# 4      Finland            7.413         1.40598  1.13464  0.81091  0.57104
#
#    generosity  government_trust  dystopia_residual continent  ...  Poisonings  \
# 0     0.36171           0.44453            2.73939    Europe  ...    0.002780
# 1     0.28083           0.41203            2.69463    Europe  ...    0.006472
# 2     0.47678           0.14975            2.83137    Europe  ...    0.001614
# 3     0.37895           0.35776            2.66465    Europe  ...    0.007180
# 4     0.25492           0.41004            2.82596    Europe  ...    0.012392
#
#       Falls  Fire, heat and hot substances  Drowning  \
# 0  0.270353                       0.026409  0.018608
# 1  0.959653                       0.010671  0.024640
# 2  0.011843                       0.000269  0.000456
# 3  0.388723                       0.022298  0.032322
# 4  0.662584                       0.030798  0.052981
#
#   Exposure to mechanical forces  Natural disasters  \
# 0                      0.009577           0.000000
# 1                      0.017170           0.001957
# 2                      0.000284           0.000000
# 3                      0.013167           0.000000
# 4                      0.018789           0.000000
#
#    Other unintentional injuries  Self-harm  Interpersonal violence  \
# 0                      0.173566   0.308668                0.031507
# 1                      0.204806   0.624527                0.021167
# 2                      0.025007   0.020120                0.002005
# 3                      0.291474   0.316696                0.015968
# 4                      0.218373   0.423061                0.032139
#
#    Collective violence and legal intervention
# 0                                    0.000295
# 1                                    0.000441
# 2                                    0.000020
# 3                                    0.000268
# 4                                    0.000278
#
# [5 rows x 167 columns]
